# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# /Users/Lucanoto/Desktop/2˚ Semestre/Ciência dos Dados/Exercícios/PNAD

# %%
dados = pd.read_excel('PNAD_2013.xlsx')
print('Pronto')
# Out:
# Pronto

# %%
dados.shape
# Out:
# (362555, 72)

# %% [markdown]
# ## Selecionando dados p/ trabalhar

# %%
selecionadas = dados[['UF','V0302','V0404','V6002','V4802','V0601','V061113','V8005','V4720']]

# %%
selecionadas
# Out:
#         UF       REGIAO  SEXO  COR  REDE  NIVEL  ALFABETIZADO  INTERNET_MOVEL  \
# 1       11        Norte     4    2    99     99             1              99
# 2       11        Norte     4    8    99     99             3              99
# 3       11        Norte     4    4     2      8             1               1
# 4       11        Norte     2    8    99     99             1               1
# 5       11        Norte     4    8     4     11             1               1
# 6       11        Norte     4    8     4     10             1               1
# 7       11        Norte     2    4    99     99             1              99
# 8       11        Norte     4    2    99     99             1              99
# 9       11        Norte     2    8    99     99             1               1
# 10      11        Norte     4    2    99     99             1               1
# 11      11        Norte     4    2     2      1             3              99
# ...

# %% [markdown]
# ## Renomeando Colunas

# %%
selecionadas.columns = ['UF','SEXO','COR','REDE','NIVEL','ALFABETIZADO','INTERNET_MOVEL', 'IDADE', 'RENDMEN']

# %%
selecionadas
# Out:
#         UF  SEXO  COR  REDE  NIVEL  ALFABETIZADO  INTERNET_MOVEL  IDADE  \
# 1       11     4    2   NaN    NaN             1             NaN     42
# 2       11     4    8   NaN    NaN             3             NaN     64
# 3       11     4    4     2      8             1               1     13
# 4       11     2    8   NaN    NaN             1               1     23
# 5       11     4    8     4     11             1               1     19
# 6       11     4    8     4     10             1               1     17
# 7       11     2    4   NaN    NaN             1             NaN     59
# 8       11     4    2   NaN    NaN             1             NaN     56
# 9       11     2    8   NaN    NaN             1               1     25
# 10      11     4    2   NaN    NaN             1               1     23
# 11      11     4    2     2      1             3             NaN      5
# 12      11     2    2   NaN    NaN             1             NaN     37
# ...

# %% [markdown]
# ## Criando a Coluna das Regiões

# %%
selecionadas.insert(1,'REGIAO',0)

# %%
selecionadas
# Out:
#         UF  REGIAO  SEXO  COR  REDE  NIVEL  ALFABETIZADO  INTERNET_MOVEL  \
# 1       11       0     4    2   NaN    NaN             1             NaN
# 2       11       0     4    8   NaN    NaN             3             NaN
# 3       11       0     4    4     2      8             1               1
# 4       11       0     2    8   NaN    NaN             1               1
# 5       11       0     4    8     4     11             1               1
# 6       11       0     4    8     4     10             1               1
# 7       11       0     2    4   NaN    NaN             1             NaN
# 8       11       0     4    2   NaN    NaN             1             NaN
# 9       11       0     2    8   NaN    NaN             1               1
# 10      11       0     4    2   NaN    NaN             1               1
# 11      11       0     4    2     2      1             3             NaN
# 12      11       0     2    2   NaN    NaN             1             NaN
# ...

# %% [markdown]
# ## Definindo as regiões de cada Estado

# %%
selecionadas.ix[selecionadas.UF <= 17,'REGIAO'] = 'Norte'
selecionadas.ix[(selecionadas.UF >=21) & (selecionadas.UF<=29),'REGIAO'] = 'Nordeste'
selecionadas.ix[(selecionadas.UF >=31) & (selecionadas.UF<=35),'REGIAO'] = 'Sudeste'
selecionadas.ix[(selecionadas.UF >=41) & (selecionadas.UF<=43),'REGIAO'] = 'Sul'
selecionadas.ix[selecionadas.UF >=50 ,'REGIAO'] = 'CentroOeste'

print('Ordem Executada')
# Out:
# Ordem Executada
# //anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:426: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
selecionadas.head(5)
# Out:
#    UF REGIAO  SEXO  COR  REDE  NIVEL  ALFABETIZADO  INTERNET_MOVEL  IDADE  \
# 1  11  Norte     4    2    99     99             1              99     42
# 2  11  Norte     4    8    99     99             3              99     64
# 3  11  Norte     4    4     2      8             1               1     13
# 4  11  Norte     2    8    99     99             1               1     23
# 5  11  Norte     4    8     4     11             1               1     19
#
#    RENDMEN
# 1      350
# 2      678
# 3        0
# 4      800
# 5        0

# %%
selecionadas.dtypes
# Out:
# UF                  int64
# REGIAO             object
# SEXO                int64
# COR                 int64
# REDE              float64
# NIVEL             float64
# ALFABETIZADO        int64
# INTERNET_MOVEL    float64
# IDADE               int64
# RENDMEN           float64
# dtype: object

# %% [markdown]
# ### Transformando os NaN's em um valor inteiro p/ facilitar

# %%
selecionadas.INTERNET_MOVEL=selecionadas.INTERNET_MOVEL.fillna(99)
selecionadas.REDE=selecionadas.REDE.fillna(99)
selecionadas.NIVEL=selecionadas.NIVEL.fillna(99)
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py:2387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
selecionadas.replace(to_replace={‘RENDMEN’: {‘999999999999’: np.nan}})

# %%
selecionadas.dtypes
# Out:
# UF                  int64
# REGIAO             object
# SEXO                int64
# COR                 int64
# REDE              float64
# NIVEL             float64
# ALFABETIZADO        int64
# INTERNET_MOVEL    float64
# IDADE               int64
# RENDMEN           float64
# dtype: object

# %%
selecionadas.to_excel('dados_prontos2.xlsx', index = True)
print('Pronto')
# Out:
# Pronto
